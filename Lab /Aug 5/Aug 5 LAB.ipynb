# %%
Student = ['Rithwik', 'Mahanand',' Ram' ,'Rohith' , 'Sai Teja' ]

Food = ['Biryani', 'Pizza',' Bugger' ,'Pasta' , 'Maggie' ]


import matplotlib.pyplot as plt
plt.scatter(Student, Food)
plt.title('Students and their Favourite Food items')
plt.ylabel('Student')
plt.xlabel('Food Items')
plt.show()
